O01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V01HO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V55HO08.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V55HO09.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V05HO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V07HO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V09HO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V04HO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V02HO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V55HO10.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V55HO11.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V06HO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V08HO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V11HO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/healthy/V03HO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V02PO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V09PO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V06PO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V08PO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V03PO07.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V11PO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V14PO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V04PO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V05PO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V10PO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V07PO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V03PO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V01PO01.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V03PO04.png
# /kaggle/input/parkinsons-drawings/drawings/wave/testing/parkinson/V14PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V55HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V10HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V04HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V11HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V08HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V08HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V06HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V02HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V02HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V12HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V07HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V09HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V55HO05.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V12HO01.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V03HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V55HO14.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V05HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V55HO15.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V55HO12.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V01HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V55HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V09HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V55HO06.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V55HO07.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V55HO04.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V10HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V11HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V04HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V06HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V55HO01.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V01HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V07HO02.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V55HO13.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V03HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V12HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/healthy/V05HO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V09PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V01PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V12PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V08PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V15PO01.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V05PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V09PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V03PO06.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V04PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V11PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V04PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V03PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V14PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V07PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V11PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V01PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V10PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V03PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V06PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V12PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V02PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V12PO01.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V06PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V03PO08.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V15PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V15PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V03PO05.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V07PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V13PO02.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V05PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V03PO09.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V13PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V13PO01.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V02PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V10PO03.png
# /kaggle/input/parkinsons-drawings/wave/training/parkinson/V08PO03.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V10HO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V01HO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V55HO08.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V55HO09.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V05HO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V07HO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V09HO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V04HO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V02HO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V55HO10.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V55HO11.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V06HO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V08HO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V11HO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/healthy/V03HO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V02PO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V09PO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V06PO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V08PO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V03PO07.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V11PO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V14PO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V04PO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V05PO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V10PO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V07PO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V03PO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V01PO01.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V03PO04.png
# /kaggle/input/parkinsons-drawings/wave/testing/parkinson/V14PO03.png

# %%
# !tree -d /kaggle/input/parkinsons-drawings/
# Out:
# /kaggle/input/parkinsons-drawings/
# ├── drawings
# │   ├── spiral
# │   │   ├── testing
# │   │   │   ├── healthy
# │   │   │   └── parkinson
# │   │   └── training
# │   │       ├── healthy
# │   │       └── parkinson
# │   └── wave
# │       ├── testing
# │       │   ├── healthy
# │       │   └── parkinson
# │       └── training
# │           ├── healthy
# │           └── parkinson
# ├── spiral
# │   ├── testing
# │   │   ├── healthy
# │   │   └── parkinson
# │   └── training
# │       ├── healthy
# │       └── parkinson
# └── wave
#     ├── testing
#     │   ├── healthy
#     │   └── parkinson
#     └── training
#         ├── healthy
#         └── parkinson
#
# 29 directories

# %%
import os
import numpy as np
import pandas as pd
from keras.optimizers import Adadelta
from keras.layers import *
from keras import backend as K
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.models import Model,load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau,EarlyStopping

#from scipy.misc import toimage,imresize
from skimage import exposure
from PIL import Image
import cv2

# %%
spirals_train_folder = '../input/parkinsons-drawings/spiral/training/'
spirals_val_folder = '../input/parkinsons-drawings/spiral/testing/'
waves_train_folder = '../input/parkinsons-drawings/wave/training/'
waves_val_folder = '../input/parkinsons-drawings/wave/testing/'

batch_size = 24

# histogram equalizer
def eqz_plz(img):
    return exposure.equalize_hist(img)


spiral_datagen = ImageDataGenerator(rotation_range=360, # they're spirals.
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    brightness_range=(0.5,1.5),
                                    shear_range=0.2,
                                    zoom_range=0.2,
                                    horizontal_flip=True,
                                    preprocessing_function=eqz_plz,
                                    vertical_flip=True)

wave_datagen = ImageDataGenerator(rotation_range=5,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  brightness_range=(0.5,1.5),
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True,
                                  preprocessing_function=eqz_plz,
                                  vertical_flip=True)


spiral_train_generator = spiral_datagen.flow_from_directory(directory=os.path.abspath(spirals_train_folder),
                                                            target_size=(256, 256),
                                                            color_mode="grayscale",
                                                            batch_size=batch_size,
                                                            class_mode="binary",
                                                            shuffle=True,
                                                            seed=666)

spiral_val_generator = spiral_datagen.flow_from_directory(directory=os.path.abspath(spirals_val_folder),
                                                            target_size=(256, 256),
                                                            color_mode="grayscale",
                                                            batch_size=batch_size,
                                                            class_mode="binary",
                                                            shuffle=True,
                                                            seed=710)

wave_train_generator = wave_datagen.flow_from_directory(directory=os.path.abspath(waves_train_folder),
                                                        target_size=(256, 512), # HxW in machine learning, WxH in computer vision
                                                        color_mode="grayscale",
                                                        batch_size=batch_size,
                                                        class_mode="binary",
                                                        shuffle=True,
                                                        seed=420)

wave_val_generator = wave_datagen.flow_from_directory(directory=os.path.abspath(waves_val_folder),
                                                        target_size=(256, 512),
                                                        color_mode="grayscale",
                                                        batch_size=batch_size,
                                                        class_mode="binary",
                                                        shuffle=True,
                                                        seed=420)
# Out:
# Found 72 images belonging to 2 classes.
# Found 30 images belonging to 2 classes.
# Found 72 images belonging to 2 classes.
# Found 30 images belonging to 2 classes.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss',patience=12,min_lr=1e-9,verbose=1)
early_stop = EarlyStopping(monitor='val_loss',patience=16,verbose=1)

# %%
K.clear_session()

def custom_model(mode):
    if (mode == 'spirals') or (mode == 'spiral'):
        input_layer = Input(shape=(256,256,1),name=f'{mode}_input_layer')
    elif (mode == 'waves') or (mode == 'wave'):
        input_layer = Input(shape=(256,512,1),name=f'{mode}_input_layer')

    m1 = Conv2D(256,(5,5),dilation_rate=4,kernel_initializer='glorot_normal',kernel_regularizer=l2(0.001),activation='relu',padding='same')(input_layer)
    p1 = MaxPool2D((9,9),strides=2)(m1)
    m2 = Conv2D(128,(5,5),dilation_rate=2,kernel_initializer='glorot_normal',kernel_regularizer=l2(0.001),activation='relu',padding='same')(p1)
    p2 = MaxPool2D((7,7),strides=2)(m2)
    m3 = Conv2D(64,(3,3),kernel_initializer='glorot_normal',kernel_regularizer=l2(0.001),activation='relu',padding='same')(p2)
    p3 = MaxPool2D((5,5),strides=2)(m3)
    f1 = Flatten()(p3)
    d1 = Dense(666,activation='relu')(f1)
    d2 = Dense(1,activation='softmax')(d1)
    
    this_model = Model(input_layer,d2)
    #this_model.summary()
    return this_model

# %%
spiral_model = custom_model(mode='spirals') # early stopping epoch 89: val_loss 0.4796, val_acc 0.8274
spiral_model.compile(optimizer=Adadelta(learning_rate=3.15e-5), loss='binary_crossentropy', metrics=['accuracy'])

# %%
spiral_model.fit_generator(spiral_train_generator,
                           validation_data=spiral_val_generator,
                           epochs=666,
                           steps_per_epoch=(2000//batch_size),
                           validation_steps=(800//batch_size),
                           verbose=1)
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# /opt/conda/lib/python3.7/site-packages/skimage/exposure/exposure.py:181: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, bin_centers = histogram(image, nbins)
# Epoch 1/666
# 83/83 [==============================] - 7s 30ms/step - loss: 0.9509 - accuracy: 0.4990 - val_loss: 0.9494 - val_accuracy: 0.5000

# %%
spiral_model.save('../output/custom_model_spirals.h5')

# %%
waves_model = custom_model(mode='waves')
waves_model.compile(optimizer=Adam(lr=3.15e-5),loss='binary_crossentropy',metrics=['accuracy'])

# %%
waves_model.fit_generator(wave_train_generator,
                          validation_data=wave_val_generator,
                          epochs=666,
                          steps_per_epoch=(2000//batch_size),
                          validation_steps=(800//batch_size),
                          
                          verbose=1)
# Out:
# Epoch 1/666
# 83/83 [==============================] - 7s 44ms/step - loss: 0.9917 - accuracy: 0.5015 - val_loss: 0.9567 - val_accuracy: 0.5000

# %%
waves_model.save('../output/custom_model_waves.h5')

# %%
doc_input = concatenate([spiral_model.output,waves_model.output])
dense_doc_1 = Dense(69,activation='relu')(doc_input)
dense_doc_2 = Dense(1,activation='sigmoid')(dense_doc_1)

# %%
def multiple_generators(gen1,gen2):
    while True:
        X1 = gen1.next()
        X2 = gen2.next()
        yield [X1[0], X2[0]], ((X1[1]+X2[1])/2)
            
input_generator = multiple_generators(spiral_train_generator,wave_train_generator)       
test_generator = multiple_generators(spiral_train_generator,wave_train_generator)      

def disable_trainable(model):
    for layer in model.layers:
        layer.trainable = False
        
disable_trainable(spiral_model)
disable_trainable(waves_model)
spiral_model.compile(optimizer=Adadelta(lr=5.11089622e-5), loss='binary_crossentropy', metrics=['accuracy'])
waves_model.compile(optimizer=Adadelta(lr=5.11089622e-5), loss='binary_crossentropy', metrics=['accuracy'])

doctor_model = Model(inputs=[spiral_model.input,waves_model.input],outputs=dense_doc_2)
doctor_model.compile(optimizer=Adadelta(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
reduce_lr_2 = ReduceLROnPlateau(monitor='val_loss',patience=8,rate=0.4,min_lr=1e-12,verbose=1)
early_stop_2 = EarlyStopping(monitor='val_loss',patience=24,verbose=1)

doctor_model.fit_generator(input_generator,
                           validation_data=test_generator,
                           epochs=666,
                           steps_per_epoch=(2000//batch_size),
                           validation_steps=(800//batch_size),
                           callbacks=[reduce_lr_2,early_stop_2],verbose=1)
# Out:
# Epoch 1/666
# 67/83 [=======================>......] - ETA: 13s - loss: 1.2142 - accuracy: 0.2461

# %%
doctor_model.save('../output/custom_model_doctor.h5')
